# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset

df=pd.read_table("")#insert dataset filepath  here
df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=50)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]



#

#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





# #visualization
# import graphviz
# from sklearn.tree import export_graphviz
# for i in range(3):
#     tree = clf.estimators_[i]
#     dot_data = export_graphviz(tree,out_file=None,
#                                feature_names=attributes,
#                                filled=True,
#                                max_depth=8,
#                                impurity=False,
#                                proportion=True,
#                                node_ids=True,class_names=["DH","NO","SL"])
#     graph = graphviz.Source(dot_data)
#     graph.format = "png"
#     graph.render("3."+str(i+1),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 89.25 %
# Sensitivity : 80.0 %
# Specificity : 82.35 %
# ------------------------------

# %% [markdown]
# num trees = 100

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset
df = pd.read_table ("" ,sep = " ")

df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]





#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





# #visualization
# import graphviz
# from sklearn.tree import export_graphviz
# for i in range(3):
#     tree = clf.estimators_[i]
#     dot_data = export_graphviz(tree,out_file=None,
#                                feature_names=attributes,
#                                filled=True,
#                                max_depth=2,
#                                impurity=False,
#                                proportion=True,
#                                node_ids=True,class_names=["DH","NO","SL"])
#     graph = graphviz.Source(dot_data)
#     graph.format = "png"
#     graph.render("4."+str(i+1),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 89.25 %
# Sensitivity : 80.0 %
# Specificity : 82.35 %
# ------------------------------

# %% [markdown]
# Num trees = 150

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset
df = pd.read_table ("" ,sep = " ")

df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=150)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]





#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





# #visualization
# import graphviz
# from sklearn.tree import export_graphviz
# for i in range(3):
#     tree = clf.estimators_[i]
#     dot_data = export_graphviz(tree,out_file=None,
#                                feature_names=attributes,
#                                filled=True,
#                                max_depth=2,
#                                impurity=False,
#                                proportion=True,
#                                node_ids=True,class_names=["DH","NO","SL"])
#     graph = graphviz.Source(dot_data)
#     graph.format = "png"
#     graph.render("5."+str(i+1),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 89.25 %
# Sensitivity : 83.33 %
# Specificity : 76.47 %
# ------------------------------

# %% [markdown]
# num trees =  200

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset
df = pd.read_table ("" ,sep = " ")

df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=200)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]





#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





# #visualization
# import graphviz
# from sklearn.tree import export_graphviz
# for i in range(3):
#     tree = clf.estimators_[i]
#     dot_data = export_graphviz(tree,out_file=None,
#                                feature_names=attributes,
#                                filled=True,
#                                max_depth=2,
#                                impurity=False,
#                                proportion=True,
#                                node_ids=True,class_names=["DH","NO","SL"])
#     graph = graphviz.Source(dot_data)
#     graph.format = "png"
#     graph.render("6."+str(i+1),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 87.1 %
# Sensitivity : 80.0 %
# Specificity : 76.47 %
# ------------------------------

# %% [markdown]
# numtrees = 250 . best performing Tree

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset
# df = pd.read_table ("" ,sep = " ")
df=pd.read_table("C:/Users/sidmo/Google Drive/Documents/CityU/Classes/CS3481 Fundamentals of Data Science/Assignment/Assignment 2/vertebral_column_data/column_3C.dat", sep =" ")
df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=250)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]





#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





#visualization
import graphviz
from sklearn.tree import export_graphviz
# for i in range(2):
# tree = clf.estimators_[100]
# dot_data = export_graphviz(tree,out_file=None,
#                            feature_names=attributes,
#                            filled=True,
#                            max_depth=2,
#                            impurity=False,
#                            proportion=True,
#                            node_ids=True,class_names=["DH","NO","SL"])
# graph = graphviz.Source(dot_data)
# graph.format = "png"
# graph.render("250."+str(100),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)

clf.feature_importances_
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 87.1 %
# Sensitivity : 80.0 %
# Specificity : 76.47 %
# ------------------------------
# array([0.12623572, 0.08156528, 0.1218418 , 0.15018498, 0.13150193,
#        0.38867028])

# %% [markdown]
# naive bayes classifier

# %%
# create tree
from sklearn.naive_bayes import GaussianNB

# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(dftrain.iloc[:,0:6],traininglabels)


attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]




from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)

GB_pred = model.predict(dftest.iloc[:,0:6])







#visualization
import graphviz
from sklearn.tree import export_graphviz
# for i in range(2):
# tree = GB_pred
# dot_data = export_graphviz(tree,out_file=None,
#                            feature_names=attributes,
#                            filled=True,
#                            max_depth=2,
#                            impurity=False,
#                            proportion=True,
#                            node_ids=True,class_names=["DH","NO","SL"])
# graph = graphviz.Source(dot_data)
# graph.format = "png"
# graph.render("NaiverBBayes",view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, GB_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, GB_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22712\675783361.py in <module>
#      34 # for i in range(2):
#      35 tree = GB_pred
# ---> 36 dot_data = export_graphviz(tree,out_file=None,
#      37                            feature_names=attributes,
#      38                            filled=True,
#
# E:\Users\sidmo\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     858     """
#     859
# --> 860     check_is_fitted(decision_tree)
#     861     own_file = False
#     862     return_string = False
#
# E:\Users\sidmo\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
clfzero = clf.estimators_[50]
clfzero_test_pred = clfzero.predict(dftest.iloc[:,0:6])

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, clfzero_test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)

clfzero.feature_importances_
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 89.25 %
# Sensitivity : 79.31 %
# Specificity : 70.59 %
# ------------------------------
# E:\Users\sidmo\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([0.07859271, 0.1549165 , 0.04333422, 0.02641705, 0.08546385,
#        0.61127567])

# %%
clfone = clf.estimators_[100]
clfone_test_pred = clfone.predict(dftest.iloc[:,0:6])

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, clfone_test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)

clfone.feature_importances_
# Out:
# ------------------------------
# On Train Data
# ------------------------------
# Accuracy    : 100.0 %
# Sensitivity : 100.0 %
# Specificity : 100.0 %
# ------------------------------
# On Test Data
# ------------------------------
# Accuracy    : 88.17 %
# Sensitivity : 79.31 %
# Specificity : 64.71 %
# ------------------------------
# E:\Users\sidmo\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([0.05170203, 0.07064647, 0.0715906 , 0.06578916, 0.09395743,
#        0.64631431])

# %% [markdown]
# numtrees =300

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# get dataset
df = pd.read_table ("" ,sep = " ")

df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]


#partition data set
dftrain,dftest =  train_test_split(df, train_size=0.7, test_size=0.3,shuffle=True, random_state=43)


# get labels
training_labels = dftrain.iloc[:,6]
test_labels = dftest.iloc[:,6]


# change non-numerical labels to integers
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
traininglabels = le.fit_transform(training_labels)
testlabels =le.fit_transform(test_labels)

# create tree
clf = RandomForestClassifier(n_estimators=300)
clf = clf.fit(dftrain.iloc[:,0:6],traininglabels)



attributes = ["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis"]





#predict
train_pred = clf.predict(dftrain.iloc[:,0:6])
test_pred = clf.predict(dftest.iloc[:,0:6])





# #visualization
# import graphviz
# from sklearn.tree import export_graphviz
# for i in range(3):
#     tree = clf.estimators_[i]
#     dot_data = export_graphviz(tree,out_file=None,
#                                feature_names=attributes,
#                                filled=True,
#                                max_depth=2,
#                                impurity=False,
#                                proportion=True,
#                                node_ids=True,class_names=["DH","NO","SL"])
#     graph = graphviz.Source(dot_data)
#     graph.format = "png"
#     graph.render("8."+str(i+1),view = True)




#accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
trainaccuracy= accuracy_score(traininglabels, train_pred)
testaccuracy= accuracy_score(testlabels, test_pred)

confusion_TRN = confusion_matrix(traininglabels, train_pred)
confusion_TST = confusion_matrix(testlabels, test_pred)

#accuracy results
TP = confusion_TRN[1,1] # true positive
TN = confusion_TRN[0,0] # true negatives
FP = confusion_TRN[0,1] # false positives
FN = confusion_TRN[1,0] # false negatives

TP_TST = confusion_TST[1,1] # true positive
TN_TST = confusion_TST[0,0] # true negatives
FP_TST = confusion_TST[0,1] # false positives
FN_TST = confusion_TST[1,0] # false negatives

trainsensitivity= TP / float(TP+FN)
trainspecificity= TN / float(TN+FP)

testsensitivity= TP_TST / float(TP_TST+FN_TST)
testspecificity= TN_TST / float(TN_TST+FP_TST)

# Let us compare the values obtained for Train & Test:
print('-'*30)
print('On Train Data')
print('-'*30)
print("Accuracy    : {} %".format(round((trainaccuracy*100),2)))
print("Sensitivity : {} %".format(round((trainsensitivity*100),2)))
print("Specificity : {} %".format(round((trainspecificity*100),2)))
print('-'*30)
print('On Test Data')
print('-'*30)
print("Accuracy    : {} %".format(round((testaccuracy*100),2)))
print("Sensitivity : {} %".format(round((testsensitivity*100),2)))
print("Specificity : {} %".format(round((testspecificity*100),2)))
print('-'*30)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22712\3039365470.py in <module>
#       4
#       5 # get dataset
# ----> 6 df = pd.read_table ("C:/Users/naras/My Drive/Documents/CityU/Classes/CS3481 Fundamentals of Data Science/Assignment/Assignment 2/vertebral_column_data/column_3C.dat" ,sep = " ")
#       7 # df=pd.read_table("C:/Users/sidmo/Google Drive/Documents/CityU/Classes/CS3481 Fundamentals of Data Science/Assignment/Assignment 2/vertebral_column_data/column_3C.dat", sep =" ")
#       8 df.columns =["pelvic incidence", "pelvic tilt", "lumbar lordosis angle", "sacral slope", "pelvic radius" , "grade of spondylolisthesis","Class"]
#
# E:\Users\sidmo\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %% [markdown]
# Naive Bayes Classifier
